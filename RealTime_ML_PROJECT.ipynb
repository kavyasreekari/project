# %%
#importing libraries
import os
import cv2
import imutils
import time 
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from imutils.video import VideoStream
import tkinter as tk
from tkinter import filedialog
from tkinter import *
# Out:
# 2025-04-24 14:36:24.167336: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load pre-trained face detection model from Caffe
txt_file_path ="/Users/kavyasreechowdary/Documents/ML Project/face_detector/deploy.prototxt"
caffemodel_weights_Path = "/Users/kavyasreechowdary/Documents/ML Project/face_detector/res10_300x300_ssd_iter_140000.caffemodel"
Pretrain_face_detection_Model = cv2.dnn.readNet(txt_file_path, caffemodel_weights_Path)

# Our trained model for classification of mask and without mask
cls_model = load_model("Resnet50_Model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import cv2
import math
import argparse
# Function to detect faces in an image and highlight
def highlightFace(net, frame, conf_threshold=0.7):
    frameOpencvDnn=frame.copy()
    # Get the height and width of the frame
    frameHeight=frameOpencvDnn.shape[0]
    frameWidth=frameOpencvDnn.shape[1]
    # Convert the image into a blob that can be fed into the network
    blob=cv2.dnn.blobFromImage(frameOpencvDnn, 1.0, (300, 300), [104, 117, 123], True, False)
    net.setInput(blob)
    detections=net.forward() #performing the forward pass to detect faces
    faceBoxes=[]
    for i in range(detections.shape[2]):
        confidence=detections[0,0,i,2]
        if confidence>conf_threshold:
            x1=int(detections[0,0,i,3]*frameWidth)
            y1=int(detections[0,0,i,4]*frameHeight)
            x2=int(detections[0,0,i,5]*frameWidth)
            y2=int(detections[0,0,i,6]*frameHeight)
            faceBoxes.append([x1,y1,x2,y2])
            cv2.rectangle(frameOpencvDnn, (x1,y1), (x2,y2), (0,255,0), int(round(frameHeight/150)), 8)
    return frameOpencvDnn,faceBoxes
# Load face, age, and gender models
faceProto = "/Users/kavyasreechowdary/Documents/ML Project/gad/opencv_face_detector.pbtxt"
faceModel = "/Users/kavyasreechowdary/Documents/ML Project/gad/opencv_face_detector_uint8.pb"
ageProto = "/Users/kavyasreechowdary/Documents/ML Project/gad/age_deploy.prototxt"
ageModel = "/Users/kavyasreechowdary/Documents/ML Project/gad/age_net.caffemodel"
genderProto = "/Users/kavyasreechowdary/Documents/ML Project/gad/gender_deploy.prototxt"
genderModel = "/Users/kavyasreechowdary/Documents/ML Project/gad/gender_net.caffemodel"



MODEL_MEAN_VALUES=(78.4263377603, 87.7689143744, 114.895847746)
ageList=['(0-2)', '(4-6)', '(8-12)', '(15-20)', '(25-32)', '(38-43)', '(48-53)', '(60-100)']
genderList=['Male','Female']

faceNet=cv2.dnn.readNet(faceModel,faceProto)
ageNet=cv2.dnn.readNet(ageModel,ageProto)
genderNet=cv2.dnn.readNet(genderModel,genderProto)

# %%
def main_func(vid_path=''):
        def Realtime_Detection_func(Video_frame, Pretrain_face_detection_Model,cls_model):
            (height, width) = Video_frame.shape[:-1]
            Img_blob = cv2.dnn.blobFromImage(Video_frame, 1.0, (224, 224),(104.0, 177.0, 123.0))
            # pass the blob through the network and obtain the face detections
            Pretrain_face_detection_Model.setInput(Img_blob)
            face_identify = Pretrain_face_detection_Model.forward()
            print(face_identify.shape)
            # initialize our list of faces, their corresponding locations,
            # and the list of predictions from our face mask network
            faces_in_frame_lst = []
            faces_location_lst = []
            model_preds_lst = []
            for i in range(0, face_identify.shape[2]):
                conf_value = face_identify[0, 0, i, 2]
                if conf_value > 0.6:

                    Rectangle_box = face_identify[0, 0, i, 3:7] * np.array([width, height, width, height])
                    (starting_PointX, starting_PointY, ending_PointX, ending_PointY) = Rectangle_box.astype("int")
                    (starting_PointX, starting_PointY) = (max(0, starting_PointX), max(0, starting_PointY))
                    (ending_PointX, ending_PointY) = (min(width - 1, ending_PointX), min(height - 1, ending_PointY))
                    face_detect = vid_frm[starting_PointY:ending_PointY, starting_PointX:ending_PointX]
                    face_RGB = cv2.cvtColor(face_detect, cv2.COLOR_BGR2RGB)
                    face_Resize = cv2.resize(face_RGB, (224, 224))
                    face_to_array = img_to_array(face_Resize)
                    face_rescale = preprocess_input(face_to_array)

                    faces_in_frame_lst.append(face_rescale)
                    faces_location_lst.append((starting_PointX, starting_PointY, ending_PointX, ending_PointY))
                    
            if len(faces_in_frame_lst) > 0:

                faces_in_frame_lst = np.array(faces_in_frame_lst, dtype="float32")
                model_preds_lst = cls_model.predict(faces_in_frame_lst, batch_size=16)

            return (model_preds_lst, faces_location_lst)
        # loop over the frames from the video stream
        if vid_path != '':
            print("starting video stream...")
            vid_stm = VideoStream(src=vid_path).start()
            #vid_stm = FileVideoStream(src=vid_path).start()
        elif vid_path == '':
            print(" starting live stream...")
            vid_stm = VideoStream(src=0).start()
        while True:

            vid_frm = vid_stm.read()
            vid_frm = imutils.resize(vid_frm, width=800)
            padding=20
            resultImg,faceBoxes=highlightFace(faceNet,vid_frm)
            if not faceBoxes:
                print("No face detected")

            (model_preds_lst, faces_location_lst) = Realtime_Detection_func(vid_frm, Pretrain_face_detection_Model, cls_model)

            for (pred,Rectangle_box,faceBox) in zip(model_preds_lst, faces_location_lst,faceBoxes):
                (starting_PointX, starting_PointY, ending_PointX, ending_PointY) = Rectangle_box
                (mask_img, NoMask_img) = pred
                
                face=vid_frm[max(0,faceBox[1]-padding):
                           min(faceBox[3]+padding,vid_frm.shape[0]-1),max(0,faceBox[0]-padding)
                           :min(faceBox[2]+padding, vid_frm.shape[1]-1)]
                blob=cv2.dnn.blobFromImage(face, 1.0, (227,227), MODEL_MEAN_VALUES, swapRB=False)
                genderNet.setInput(blob)
                genderPreds=genderNet.forward()
                gender=genderList[genderPreds[0].argmax()]
                print(f'Gender: {gender}')

                ageNet.setInput(blob)
                agePreds=ageNet.forward()
                age=ageList[agePreds[0].argmax()]
                print(f'Age: {age[1:-1]} years')

                label = "Mask" if mask_img > NoMask_img else "No Mask"
                color = (0, 255, 0) if label == "Mask" else (0, 0, 255)

                cv2.putText(vid_frm, label+':'+f'   {gender}, {age}', (starting_PointX, starting_PointY - 10),cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2)
                cv2.rectangle(vid_frm, (starting_PointX, starting_PointY), (ending_PointX, ending_PointY), color, 2)

            cv2.imshow("Video Frame", vid_frm)
            key = cv2.waitKey(1) & 0xFF
            if key == ord("q"):
                break
        cv2.destroyAllWindows()
        vid_stm.stop()
#The code processes real-time video streams, detecting faces using a pre-trained SSD model. 
#Each detected face is resized and preprocessed for further predictions. 
#The MobileNetV2 model classifies whether the person is wearing a mask, while AgeNet and GenderNet predict the person’s age and gender. 
#The predictions are displayed on the video feed with bounding boxes and labels.
# The live stream continues until the user presses "q" to stop the process.

# %%
def exit():
    #window.destroy()
    window.quit()

# %%
def main():
    # Function for opening the
    # file explorer window
    def browseFiles():
        filename = filedialog.askopenfilename(initialdir = "/",
                                            title = "Select a File",
                                            filetypes = (("Text files",
                                                            "*.mp4"),
                                                        ("all files",
                                                            "*.*")))
        # Change label contents
        label_file_explorer.configure(text="File Opened: "+filename)
        return(filename)
    window = Tk()
    window.title('Face Mask Detection')
    window.geometry("500x500")
    window.config(background = "white")
    label_file_explorer = Label(window,
                                text = "Face mask Detection using Tkinter",
                                width = 100, height = 4,
                                fg = "blue")
    button_explore = Button(window,
                            text = "Browse Files",
                            command = browseFiles)
    button_live_stream=Button(window,
                        text = "Live Stream",
                        command = main_func)
    button_video_stream=Button(window,
                        text = "Video Stream",
                        command = lambda: main_func(browseFiles()))

    button_exit = Button(window,
                        text = "Exit",
                        command = exit)

    button_live_stream.grid(column = 1,row = 4)

    button_video_stream.grid(column = 1,row = 5)

    button_exit.grid(column = 1,row = 6)
    # Let the window wait for any events
    window.mainloop()

# %%
if __name__ =="__main__":
    main()
# Out:
#  starting live stream...
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Gender: Male
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Male
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 25-32 years
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
#  starting live stream...
# No face detected
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Male
# Age: 15-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Gender: Male
# Age: 8-12 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 38-43 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Gender: Female
# Age: 48-53 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Female
# Age: 38-43 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# Gender: Female
# Age: 38-43 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Gender: Female
# Age: 38-43 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 15-20 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 8-12 years
#  starting live stream...
# No face detected
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 4-6 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 15-20 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Gender: Male
# Age: 4-6 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Male
# Age: 0-2 years
# No face detected
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Male
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Gender: Female
# Age: 8-12 years
# (1, 1, 200, 7)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Gender: Female
# Age: 25-32 years
# (1, 1, 200, 7)
